# %% [markdown]
# Guia de Python

# %%
print("Hello World!!") # Comentarios
casa="2 pisos" # Declaracion de variables
callecasa=9
numbA=13
numbB=9
#Operaciones
opAB=numbA+numbB
print(opAB)
opAB=numbA%numbB #modulo
print(opAB)
opAB=numbA**numbB #potencia
print(opAB)
#conversion de variables
print(type(opAB)) #nos da el tipo de variable
numbc=2
conv=float(numbc)
print(conv)
conv=int(conv)
print(conv)
Strg="21"
conv=float(Strg)
print(conv)
10.0.is_integer() #se valida si es int y devuelve true
#10.2.is_integer()
(10).bit_length()# cantidad de bits
#retorna  true o false si es booleano
#bool(0)
#bool("")
bool([])
int(False)
2<5
#Strings
stringc="""Con triple comilla doble"""
stringd='can\'t'#caracter escapado
stringe="can't"
Concatenado="yo "+stringd +" "+ stringc
print(Concatenado)
len("Adrian")
#unir string
" :o ".join(["Martinez","Lizarazo"])
#Mayusculas y Minusculas
"MINUSCULAS".lower()
"mayusculas".upper()

#Formas de llamar variables con formato
edad= 34
emp= "Data"

"Yo tengo {0} años y estudio Big {1}".format(edad,emp)
f"Yo tengo {edad} y estudio Big {emp}"

#Extrae caracteres de un string
print(emp[2])

#Extraer partes de un string
fullname ="Victor Adrian Martinez Lizarazo"
fullname[7:13]

#Extrae solo  hasta las posiciones indicada
fullname[7:] #los quita los 7 primeros
fullname[:3] # solo extrae los primero 3
fullname[:] #toda la cadena

#Extraemos un solo caracter
fullname[3]

#Extraemos desde atras, -1, -2, -3, etc
fullname[-1]

#Listas, pueden contener varios tipos de datos almacenados
mixData=["Nombre",1090400333,[1,2,3]]
print(mixData[2])
print(mixData[-1])

data2 = mixData[0:1]
mixData[2][2]

#concatenar lista
list2= data2 + mixData
list2
len(list2)

#append
list2.append(12)
#Ordenar cuando son del mismo tipo de dato
list3=[3,2,4,5,1]
list3.sort()
print(list3)
#Eliminar datos de lista
list2.pop(1)
print(list2)
#rebanado de listas es igual que las cadenas string
list2[1:2]

#Diccionarios
dicprueba=dict() #SE crea el diccionario
dicprueba["one"]="uno" #Se asigna o se agrega una llave y valor del elemento del diccionario
dicprueba.keys() #pueden ver las llaves
dicprueba.values() #pueden ver los valores

#TUPLESSSSSS
# Out:
# Hello World!!
# 22
# 4
# 10604499373
# <class 'int'>
# 2.0
# 2
# 21.0
# yo can't Con triple comilla doble
# t
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3, 4, 5]
# ['Nombre', 1090400333, [1, 2, 3], 12]
